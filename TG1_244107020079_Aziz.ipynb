# %% [markdown]
# <a href="https://colab.research.google.com/github/Minzizz/244107020079_ML2026/blob/main/TG1_244107020079_Aziz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mne

# %% [markdown]
# # Bagian 1
#
# ## Library Python
#
#
# 1.   PyPREP
#
#       *  Digunakan untuk preprocessing data EEG (Rekaman Gelombang Otak)
#
# 2.   Scipy
#       *  Tools komputasi sains dan matematika tingkat lanjut di python, yang dibuat diatas NumPy
#
# 3. wandb
#       * Tools untuk track perkembangan Machine Learning
#
# 4. pyECG
#       * Library yang fokus untuk memproses dan menganalisis data ECG (electrocardiogram)
#
# # Bagian 2
#
# Berikan contoh tentang tidakan melanggar etika dan hukum tentang penggunaan kecerdasan buatan. Sertakan referensi yang digunakan.
#       *
#
#
# Berikan contoh tentang dampak energi dan lingkungan terhadap pemanfaatan kecerdasan buatan dan bagaimana cara mengatasinya (Anda dapat memberikan pendapat pribadi). Sertakan referensi yang digunakan.
#       *
